# %%
5+5
# Out:
# 10

# %%
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in d:\data_science project\resume\venv\lib\site-packages (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain_huggingface) (0.30.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in d:\data_science project\resume\venv\lib\site-packages (from langchain_huggingface) (0.3.51)
# Requirement already satisfied: sentence-transformers>=2.6.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain_huggingface) (4.0.2)
# Requirement already satisfied: tokenizers>=0.19.1 in d:\data_science project\resume\venv\lib\site-packages (from langchain_huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain_huggingface) (4.51.0)
# Requirement already satisfied: filelock in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\data_science project\resume\venv\lib\site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.13.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.3.26)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.33)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.11.2)
# Requirement already satisfied: torch>=1.11.0 in d:\data_science project\resume\venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.6.0)
# Requirement already satisfied: scikit-learn in d:\data_science project\resume\venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.6.1)
# Requirement already satisfied: scipy in d:\data_science project\resume\venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: Pillow in d:\data_science project\resume\venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (11.1.0)
# Requirement already satisfied: numpy>=1.17 in d:\data_science project\resume\venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\data_science project\resume\venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in d:\data_science project\resume\venv\lib\site-packages (from transformers>=4.39.0->langchain_huggingface) (0.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in d:\data_science project\resume\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2025.1.31)
# Requirement already satisfied: networkx in d:\data_science project\resume\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.2.1)
# Requirement already satisfied: jinja2 in d:\data_science project\resume\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in d:\data_science project\resume\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\data_science project\resume\venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: colorama in d:\data_science project\resume\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain_huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in d:\data_science project\resume\venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\data_science project\resume\venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.6.0)
# Requirement already satisfied: anyio in d:\data_science project\resume\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in d:\data_science project\resume\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\data_science project\resume\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\data_science project\resume\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.0.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\data_science project\resume\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\data_science project\resume\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.3.1)

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in d:\data_science project\resume\venv\lib\site-packages (0.30.1)
# Requirement already satisfied: filelock in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (4.13.1)
# Requirement already satisfied: colorama in d:\data_science project\resume\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in d:\data_science project\resume\venv\lib\site-packages (1.1.0)

# %%
import os 
from dotenv import load_dotenv
load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in d:\data_science project\resume\venv\lib\site-packages (0.30.1)
# Requirement already satisfied: filelock in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\data_science project\resume\venv\lib\site-packages (from huggingface_hub) (4.13.1)
# Requirement already satisfied: colorama in d:\data_science project\resume\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\data_science project\resume\venv\lib\site-packages (from requests->huggingface_hub) (2025.1.31)

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in d:\data_science project\resume\venv\lib\site-packages (0.3.21)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (0.3.51)
# Requirement already satisfied: langchain<1.0.0,>=0.3.23 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (0.3.23)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (3.11.16)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in d:\data_science project\resume\venv\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\data_science project\resume\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\data_science project\resume\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\data_science project\resume\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\data_science project\resume\venv\lib\site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\data_science project\resume\venv\lib\site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (2.11.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\data_science project\resume\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (4.13.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\data_science project\resume\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\data_science project\resume\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data_science project\resume\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\data_science project\resume\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data_science project\resume\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\data_science project\resume\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in d:\data_science project\resume\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in d:\data_science project\resume\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in d:\data_science project\resume\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\data_science project\resume\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\data_science project\resume\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\data_science project\resume\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\data_science project\resume\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\data_science project\resume\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in d:\data_science project\resume\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
HUGGING_FACE_token=os.getenv("HUGGING_FACE")

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"

llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    temperature=0.7,
    task="text-generation",
    model_kwargs={"max_length": 150},
    huggingfacehub_api_token=HUGGING_FACE_token
)
llm

# %%
llm.invoke("What is Machine Learning")
# Out:
# d:\Data_Science Project\resume\venv\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# '?\n\nMachine Learning (ML) is a subset of Artificial Intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine learning focuses on the development of computer programs that can access data and use it to learn for themselves.\n\nThe process of learning begins with observations or data, such as examples, direct experience, or instruction, in order to look for patterns in data and make better decisions in the future based on the examples that we provide. The primary aim is to allow the computers to learn automatically without human intervention or assistance and adjust actions accordingly.\n\nTypes of Machine Learning\n\n1. Supervised Learning\n\nSupervised learning is the most common type of machine learning. In supervised learning, the model is provided with a labeled dataset, where the input data is accompanied by the correct output or target variable. The model learns to predict the output for new, unseen data based on the patterns in the labeled dataset.\n\n2. Unsupervised Learning\n\nUnsupervised learning is a type of machine learning where the model is not provided with labeled data. Instead, it learns to identify patterns and relationships in the input data on its own. The goal of unsupervised learning is to find hidden structures or groupings within the data.\n\n3. Semi-Supervised Learning\n\nSemi-supervised learning is a combination of supervised and unsupervised learning. It uses a small amount of labeled data along with a large amount of unlabeled data to train the model. The model learns to predict the output for new, unseen data based on the patterns in both the labeled and unlabeled data.\n\n4. Reinforcement Learning\n\nReinforcement learning is a type of machine learning where an agent learns to make decisions by taking actions in an environment to achieve a goal. The agent receives rewards or penalties based on its actions, and the goal is to maximize the total reward over time.\n\nApplications of Machine Learning\n\n1. Natural Language Processing (NLP)\n\nNLP is a field of AI that focuses on the interaction between computers and human language. Machine learning is used to develop NLP models that can understand, interpret, and generate human language. Applications of NLP include chatbots, voice assistants, and text summarization.\n\n2. Image Recognition\n\nImage recognition is the ability of a computer to identify'
